# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit579-pixel/SL-2/blob/main/Ass1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.arange(-10,10,1)
y=1/(1+np.exp(x))
# y
# x
plt.plot(x,y)
plt.grid()
